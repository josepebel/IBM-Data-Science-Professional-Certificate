# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **José Antonio Peño**
#
# 100% Human

# %% [markdown]
# *I am interested in data science because I think that is the future*

# %% [markdown]
# ### The following cell is my code

# %%
x = 1
y = x - 4
z = (x-6) + y * (y-1)
z
# Out:
# 7

# %% [markdown]
# My table
#
# |    product    |     units     |     price     |
# | ------------- | ------------- | ------------- |
# |  chocolate    |       9       |     25       |
# |     milk      |       6       |      6       |
#
#
# My ordered list
#
# 1. Item 1
# 1. Item 2
# 1. Item 3
#    1. Item 3a
#    1. Item 3b
#
# My link
#
# [A simple link](https://www.google.com)
